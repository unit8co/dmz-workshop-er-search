# %% [markdown]
# # 1. Setup

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Run a local elasticsearch
# https://www.elastic.co/guide/en/elasticsearch/reference/current/docker.html#docker-cli-run-dev-mode
#
# ```bash
# docker run -d -p 9200:9200 -p 9300:9300 -e "discovery.type=single-node" docker.elastic.co/elasticsearch/elasticsearch:7.4.1
# ```

# %%
# make sure ES is up and running
import requests
res = requests.get('http://localhost:9200/'); res.json()
# Out:
# {'name': '3281a7602ad6',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': '5qOYBQSUTE2pdI6QLfpY7g',
#  'version': {'number': '7.4.1',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': 'fc0eeb6e2c25915d63d871d344e3d0b45ea0ea1e',
#   'build_date': '2019-10-22T17:16:35.176724Z',
#   'build_snapshot': False,
#   'lucene_version': '8.2.0',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %% [markdown]
# ### Install dependencies

# %%
# !pip install elasticsearch pandas
# Out:
# Requirement already satisfied: elasticsearch in /Users/gg/anaconda3/lib/python3.7/site-packages (7.0.5)
# Requirement already satisfied: pandas in /Users/gg/anaconda3/lib/python3.7/site-packages (0.23.4)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/gg/anaconda3/lib/python3.7/site-packages (from elasticsearch) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/gg/anaconda3/lib/python3.7/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /Users/gg/anaconda3/lib/python3.7/site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /Users/gg/anaconda3/lib/python3.7/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in /Users/gg/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import pandas as pd
pd.set_option('display.max_colwidth', 500) 
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Create elastic client

# %% [markdown]
# Please use TLS for other than local dev!

# %%
es_client = Elasticsearch('http://localhost:9200')

# %% [markdown]
# # 2. Get and load some data

# %% [markdown]
# ### Load dataset

# %%
# Dataset of products sold on some selected ecommerce websites (e.g. best buy)
url = "https://raw.githubusercontent.com/algolia/datasets/master/ecommerce/records.json"
df = pd.read_json(url).set_index('objectID').rename(columns={"name": "product_name"}); len(df)
# Out:
# 10000

# %%
df.columns
# Out:
# Index(['brand', 'categories', 'description', 'free_shipping',
#        'hierarchicalCategories', 'image', 'product_name', 'popularity',
#        'price', 'price_range', 'rating', 'type', 'url'],
#       dtype='object')

# %%
df.head(2)
# Out:
#              brand  \
# objectID
# 1696302   Pogoplug
# 9131042     360fly
#
#                                                                                        categories  \
# objectID
# 1696302                                           [Best Buy Gift Cards, Entertainment Gift Cards]
# 9131042   [Cameras & Camcorders, Digital Cameras, Point & Shoot Cameras, 360 & Panoramic Cameras]
#
#                                                                                                                                                                                                                                                                                                                                                                                  description  \
# objectID
# 1696302                                                                                                                                                Enjoy 3 years of unlimited Cloud storage service with this activation card, which allows you to remotely access your favorite music, movies and other media via a compatible device and enables private file sharing with loved ones.
# 9131042   Only at Best Buy  This 360fly panoramic 360&#176; HD video camera features Wi-Fi, a Bluetooth LE interface and the included 360fly app (download required), so you can easily shoot, edit, replay and share recorded video footage using a compatible iOS or Android smartphone. Included action camera adaptor lets you use your 360fly camera with your existing 3-prong mounts.
#
#           free_shipping  \
# objectID
# 1696302            True
# 9131042           False
#
#                                                                                                                                                                                                                                                     hierarchicalCategories  \
# objectID
# 1696302                                                                                                                                                                          {'lvl0': 'Best Buy Gift Cards', 'lvl1': 'Best Buy Gift Cards > Entertainment Gift Cards'}
# 9131042   {'lvl0': 'Cameras & Camcorders', 'lvl1': 'Cameras & Camcorders > Digital Cameras', 'lvl2': 'Cameras & Camcorders > Digital Cameras > Point & Shoot Cameras', 'lvl3': 'Cameras & Camcorders > Digital Cameras > Point & Shoot Cameras > 360 & Panoramic Cameras'}
#
#                                                         image  \
# objectID
# 1696302   https://cdn-demo.algolia.com/bestbuy/1696302_sc.jpg
# 9131042   https://cdn-demo.algolia.com/bestbuy/9131042_rb.jpg
#
#                                                             product_name  \
# objectID
# 1696302   3-Year Unlimited Cloud Storage Service Activation Card - Other
# 9131042                  360fly - Panoramic 360° HD Video Camera - Black
#
#           popularity   price price_range  rating                      type  \
# objectID
# 1696302        10000   69.00    50 - 100       2        Online data backup
# 9131042         9999  399.99   200 - 500       5  Point&#38;shoot camcrder
#
#                                                                                                                                                                                      url
# objectID
# 1696302   http://www.bestbuy.com/site/3-year-unlimited-cloud-storage-service-activation-card-other/1696302.p?id=1219066776306&skuId=1696302&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 9131042                     http://www.bestbuy.com/site/360fly-panoramic-360-hd-video-camera-black/9131042.p?id=1219405459683&skuId=9131042&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W

# %% [markdown]
# ### Load Data to Elasticsearch

# %% [markdown]
# **Elasticsarch Documents:**
#
# * _index:    Indicating to which index the documents belong
# * _id:       Unique ID of your document (useful to easily update / remove)
# * _source:   Contains the fields of your document

# %%
def doc_generator(df, es_index):
    return ({
            "_index": es_index,
            "_id": idx,
            "_source": es_record.to_dict(),
    } for idx, es_record in df.iterrows())

# %% [markdown]
# Loading data in bulk to Elasticsearch

# %%
def load_data(es_client, es_index, df):
    return helpers.bulk(
        client=es_client,
        actions=doc_generator(df, es_index=es_index)
    )

# %%
load_data(es_client, 'test_index', df)
# Out:
# (10000, [])

# %% [markdown]
# # 2. Query Elasticsearch

# %% [markdown]
# Many different query are provided in Elasticsearch. Let's start by retrieving a single document:

# %%
# Query 1 of the documents
import json

print(json.dumps(
    es_client.get(index='test_index', id='1696302'),
    indent=2)
 )
# Out:
# {
#   "_index": "test_index",
#   "_type": "_doc",
#   "_id": "1696302",
#   "_version": 1,
#   "_seq_no": 0,
#   "_primary_term": 1,
#   "found": true,
#   "_source": {
#     "brand": "Pogoplug",
#     "categories": [
#       "Best Buy Gift Cards",
#       "Entertainment Gift Cards"
#     ],
#     "description": "Enjoy 3 years of unlimited Cloud storage service with this activation card, which allows you to remotely access your favorite music, movies and other media via a compatible device and enables private file sharing with loved ones.",
#     "free_shipping": true,
#     "hierarchicalCategories": {
#       "lvl0": "Best Buy Gift Cards",
#       "lvl1": "Best Buy Gift Cards > Entertainment Gift Cards"
#     },
#     "image": "https://cdn-demo.algolia.com/bestbuy/1696302_sc.jpg",
#     "product_name": "3-Year Unlimited Cloud Storage Service Activation Card - Other",
#     "popularity": 10000,
#     "price": 69.0,
#     "price_range": "50 - 100",
#     "rating": 2,
#     "type": "Online data backup",
#     "url": "http://www.bestbuy.com/site/3-year-unlimited-cloud-storage-service-activation-card-other/1696302.p?id=1219066776306&skuId=1696302&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W"
#   }
# }

# %% [markdown]
# ### The "query_string"

# %% [markdown]
# Using the search API of Elasticsearch (https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-query-string-query.html)

# %%
def query_elasticsearch(index, query):
    return es_client.search(
        index=index,
        body=query
    )

# %% [markdown]
# Returns documents based on a provided query string

# %%
def basic_query_string(search_terms):
    return {
        "query": {
            "query_string" : {
                "query" : search_terms
            }
        }
    }

# %% [markdown]
# Let's try a simple query

# %%
resp = query_elasticsearch("test_index", basic_query_string("car audio"))

# %% [markdown]
# Let's build a small function to display nicely the JSON obtain in response

# %%
from pandas.io.json import json_normalize

def display_results(resp):
    return json_normalize(resp['hits']['hits'])

# %%
display_results(resp)[:5]
# Out:
#        _id      _index     _score       _source.brand  \
# 0  3500126  test_index  12.722499             Kenwood
# 1  9225581  test_index   9.579858  Griffin Technology
# 2  8063027  test_index   9.308393             Pioneer
# 3  7456254  test_index   9.099531             Pioneer
# 4  7551355  test_index   8.876576              Alpine
#
#                                                                                          _source.categories  \
# 0  [Car Electronics & GPS, Car Audio, Car Stereo Receivers, In-Dash with HD Radio, Built-In HD Radio Decks]
# 1                                                             [Audio, Cables & Chargers, MP3 Player Cables]
# 2                                      [Car Electronics & GPS, Car Audio, Car Speakers, 5.25" Car Speakers]
# 3                                    [Car Electronics & GPS, Car Audio, Car Speakers, 6" x 9" Car Speakers]
# 4                                      [Car Electronics & GPS, Car Audio, Car Speakers, 5.25" Car Speakers]
#
#                                                                                                                                                                                                                                                                                                                                         _source.description  \
# 0                                                                                            Enjoy your favorite music with this Kenwood KDC-BT762HD in-dash deck, which features CD and MP3 playback, plus Apple&#174; iPhone&#174; and iPod&#174; and Android connectivity for versatile playback options. Built-in Bluetooth enables wireless streaming.
# 1                                                                                                                                                                                                                                               Easily connect a portable audio device to your home or car stereo system with this convenient coiled cable.
# 2                                                                                                                   Enjoy your favorite music in your car with these Pioneer TS-G1345R 2-way car speakers, which feature 250W maximum power handling to deliver sounds in robust detail. The rubber-coated cloth surrounds help ensure high-fidelity audio.
# 3  Pioneer TS-A6965R Car Speakers: If you love listening to music in your car, it's time to upgrade from your factory speakers. These Pioneer speakers deliver the in-car audio experience you want for real driving enjoyment. Geek Squad&#174; installation is strongly recommended for this product. Please visit your local Best Buy store for details.
# 4                                                                                                                      Upgrade your car audio system with these Alpine Type-S SPS-510 2-way coaxial car speakers, which handle up to 170W peak power and feature 5-1/4" poly-mica woofer cones and 3/4" silk-dome tweeters for a wide range of frequencies.
#
#    _source.free_shipping _source.hierarchicalCategories.lvl0  \
# 0                  False               Car Electronics & GPS
# 1                  False                               Audio
# 2                  False               Car Electronics & GPS
# 3                  False               Car Electronics & GPS
# 4                  False               Car Electronics & GPS
#
#   _source.hierarchicalCategories.lvl1  \
# 0   Car Electronics & GPS > Car Audio
# 1           Audio > Cables & Chargers
# 2   Car Electronics & GPS > Car Audio
# 3   Car Electronics & GPS > Car Audio
# 4   Car Electronics & GPS > Car Audio
#
#                         _source.hierarchicalCategories.lvl2  \
# 0  Car Electronics & GPS > Car Audio > Car Stereo Receivers
# 1             Audio > Cables & Chargers > MP3 Player Cables
# 2          Car Electronics & GPS > Car Audio > Car Speakers
# 3          Car Electronics & GPS > Car Audio > Car Speakers
# 4          Car Electronics & GPS > Car Audio > Car Speakers
#
#                                                 _source.hierarchicalCategories.lvl3  \
# 0  Car Electronics & GPS > Car Audio > Car Stereo Receivers > In-Dash with HD Radio
# 1                                                                               NaN
# 2             Car Electronics & GPS > Car Audio > Car Speakers > 5.25" Car Speakers
# 3           Car Electronics & GPS > Car Audio > Car Speakers > 6" x 9" Car Speakers
# 4             Car Electronics & GPS > Car Audio > Car Speakers > 5.25" Car Speakers
#
#                                                                           _source.hierarchicalCategories.lvl4  \
# 0  Car Electronics & GPS > Car Audio > Car Stereo Receivers > In-Dash with HD Radio > Built-In HD Radio Decks
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4                                                                                                         NaN
#
#                                          _source.image  _source.popularity  \
# 0  https://cdn-demo.algolia.com/bestbuy/3500126_sb.jpg                4712
# 1  https://cdn-demo.algolia.com/bestbuy/9225581_sb.jpg                6413
# 2  https://cdn-demo.algolia.com/bestbuy/8063027_sb.jpg                2101
# 3  https://cdn-demo.algolia.com/bestbuy/7456254_sb.jpg                2095
# 4  https://cdn-demo.algolia.com/bestbuy/7551355_sb.jpg                9899
#
#    _source.price _source.price_range  \
# 0         169.99           100 - 200
# 1          22.99              1 - 50
# 2          49.99              1 - 50
# 3          79.99            50 - 100
# 4          89.99            50 - 100
#
#                                                                                               _source.product_name  \
# 0  Kenwood - CD - Built-in Bluetooth - Built-In HD Radio - In-Dash Deck with Detachable Faceplate - Variable Color
# 1                                         Griffin Technology - StereoConnect Cable for Most Portable Audio Devices
# 2                                     Pioneer - 5-1/4" 2-Way Car Speakers with IMPP Composite Cones (Pair) - Black
# 3                            Pioneer - 6" x 9" 3-Way Car Speakers with Multilayer Mica Matrix Cones (Pair) - Black
# 4                            Alpine - Type-S 5-1/4" 2-Way Coaxial Car Speakers with Poly-Mica Cones (Pair) - Black
#
#    _source.rating  _source.type  \
# 0               3      Cd decks
# 1               5  Connectivity
# 2               2      Speakers
# 3               2      Speakers
# 4               5      Speakers
#
#                                                                                                                                                                                                                _source.url  \
# 0  http://www.bestbuy.com/site/kenwood-cd-built-in-bluetooth-built-in-hd-radio-in-dash-deck-with-detachable-faceplate-variable-color/3500126.p?id=1219582881375&skuId=3500126&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 1                                 http://www.bestbuy.com/site/griffin-technology-stereoconnect-cable-for-most-portable-audio-devices/9225581.p?id=1218062421800&skuId=9225581&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 2                                  http://www.bestbuy.com/site/pioneer-5-1-4-2-way-car-speakers-with-impp-composite-cones-pair-black/8063027.p?id=1219309055448&skuId=8063027&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 3                          http://www.bestbuy.com/site/pioneer-6-x-9-3-way-car-speakers-with-multilayer-mica-matrix-cones-pair-black/7456254.p?id=1218846426021&skuId=7456254&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 4                         http://www.bestbuy.com/site/alpine-type-s-5-1-4-2-way-coaxial-car-speakers-with-poly-mica-cones-pair-black/7551355.p?id=1218853533848&skuId=7551355&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
#
#   _type
# 0  _doc
# 1  _doc
# 2  _doc
# 3  _doc
# 4  _doc

# %% [markdown]
# The results are showing some audio cables that have little to do with a car ...

# %% [markdown]
# ### Field Boosting

# %% [markdown]
# We can boost specific field in our query (https://www.elastic.co/guide/en/elasticsearch/reference/current/mapping-boost.html)

# %%
# Give higher weight to categories
def query_with_weight(search_terms):
    return {
        "query": {
            "query_string" : {
                "query" : search_terms,
                "fields": [
                    "description^2",
                    "categories^3",
                    "product_name^2",
                    "brand",
                    "type"
                ]
            }
        }
    }

resp = query_elasticsearch("test_index", query_with_weight("car audio"))
display_results(resp)[:10]
# Out:
#        _id      _index     _score _source.brand  \
# 0  4769785  test_index  19.982872        Alpine
# 1  9597106  test_index  19.982872        Alpine
# 2  8815536  test_index  19.982872        Alpine
# 3  8480035  test_index  19.982872           JBL
# 4  3581048  test_index  19.982872       Kenwood
# 5  4868454  test_index  19.982872       Kenwood
# 6  7705054  test_index  19.982872        Kicker
# 7  7739042  test_index  19.982872        Kicker
# 8  7738089  test_index  19.982872        Kicker
# 9  7704107  test_index  19.982872        Kicker
#
#                                    _source.categories  \
# 0  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 1  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 2  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 3  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 4  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 5  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 6  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 7  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 8  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 9  [Car Electronics & GPS, Car Audio, Car Subwoofers]
#
#                                                                                                                                                                                                                                               _source.description  \
# 0                                                  Listen to music in your vehicle with rich, clear sound with this Alpine SWS-12D4 12" dual-voice-coil 4-ohm subwoofer that features improved thermal capacity and mechanical strength for reliable performance.
# 1     Amplify the bass in your vehicle using this Alpine PWE-S8 subwoofer system that features a compact design you can fit beneath or behind a truck seat, in a sedan trunk or in the hatchback of an SUV. The cast-metal construction ensures long-lasting use.
# 2         Enhance your vehicle's audio system with this Alpine Bassline SWA-12S4 single-voice-coil, 4-ohm subwoofer that handles up to 750W peak power and features a 12" polypropylene/mica woofer cone with a UV-resistant poly foam surround for robust sound.
# 3                       Enjoy powerful low-end sound while you're on the road with this JBL CX Series CX1200 single-voice-coil subwoofer, which features a 12" polypropylene woofer cone for rich, robust audio. The progressive spider delivers optimal control.
# 4  Jam out to your favorite tunes in your vehicle with this 12" Kenwood KFC-W3016PS subwoofer, which features an oversize diaphragm and handles up to 2000W of power (400W RMS) for intense audio. Dual ventilation helps keep the speaker operating efficiently.
# 5                                Experience high-quality sound with this Kenwood Performance Series KFC-W12PS single-voice-coil 4-ohm subwoofer that features a 12" polypropylene cone with a Diamond Array pattern for dynamic sound and enhanced cone strength.
# 6        Enhance your vehicle's audio system with this Kicker CompR 40CWR102 dual-voice-coil 2-ohm subwoofer that features a 10" injection-molded polypropylene cone for rich, deep sound. Quad Venting slots help ensure cool operation for optimal performance.
# 7         This Kicker CompR 40CWR122 subwoofer features a 12" injection-molded polypropylene woofer cone and a large-diameter, progressive-roll spider with Spiralead tinsel leads to enhance your vehicle's music, so you can enjoy rich, crisp audio on the go.
# 8                                         Enhance your vehicle's audio system with this Kicker CompS 40CWS104 single-voice-coil subwoofer that features a 10" polypropylene woofer cone and handles up to 600W peak power to deliver an intense audio experience.
# 9    Enjoy your music with this Kicker CompS 40CWS124 single-voice-coil 4-ohm subwoofer, which features a 12" polypropylene cone with a foam surround for rich sound. The rip-resistant, large-diameter spider with Spiralead technology helps ensure durability.
#
#    _source.free_shipping _source.hierarchicalCategories.lvl0  \
# 0                  False               Car Electronics & GPS
# 1                  False               Car Electronics & GPS
# 2                   True               Car Electronics & GPS
# 3                  False               Car Electronics & GPS
# 4                  False               Car Electronics & GPS
# 5                  False               Car Electronics & GPS
# 6                  False               Car Electronics & GPS
# 7                  False               Car Electronics & GPS
# 8                  False               Car Electronics & GPS
# 9                  False               Car Electronics & GPS
#
#   _source.hierarchicalCategories.lvl1  \
# 0   Car Electronics & GPS > Car Audio
# 1   Car Electronics & GPS > Car Audio
# 2   Car Electronics & GPS > Car Audio
# 3   Car Electronics & GPS > Car Audio
# 4   Car Electronics & GPS > Car Audio
# 5   Car Electronics & GPS > Car Audio
# 6   Car Electronics & GPS > Car Audio
# 7   Car Electronics & GPS > Car Audio
# 8   Car Electronics & GPS > Car Audio
# 9   Car Electronics & GPS > Car Audio
#
#                   _source.hierarchicalCategories.lvl2  \
# 0  Car Electronics & GPS > Car Audio > Car Subwoofers
# 1  Car Electronics & GPS > Car Audio > Car Subwoofers
# 2  Car Electronics & GPS > Car Audio > Car Subwoofers
# 3  Car Electronics & GPS > Car Audio > Car Subwoofers
# 4  Car Electronics & GPS > Car Audio > Car Subwoofers
# 5  Car Electronics & GPS > Car Audio > Car Subwoofers
# 6  Car Electronics & GPS > Car Audio > Car Subwoofers
# 7  Car Electronics & GPS > Car Audio > Car Subwoofers
# 8  Car Electronics & GPS > Car Audio > Car Subwoofers
# 9  Car Electronics & GPS > Car Audio > Car Subwoofers
#
#                                          _source.image  _source.popularity  \
# 0  https://cdn-demo.algolia.com/bestbuy/4769785_sb.jpg                9915
# 1  https://cdn-demo.algolia.com/bestbuy/9597106_sb.jpg                9907
# 2  https://cdn-demo.algolia.com/bestbuy/8815536_sb.jpg                9906
# 3  https://cdn-demo.algolia.com/bestbuy/8480035_sb.jpg                4938
# 4  https://cdn-demo.algolia.com/bestbuy/3581048_sb.jpg                4729
# 5  https://cdn-demo.algolia.com/bestbuy/4868454_rb.jpg                4708
# 6  https://cdn-demo.algolia.com/bestbuy/7705054_sb.jpg                4622
# 7  https://cdn-demo.algolia.com/bestbuy/7739042_sb.jpg                4620
# 8  https://cdn-demo.algolia.com/bestbuy/7738089_sb.jpg                4618
# 9  https://cdn-demo.algolia.com/bestbuy/7704107_sb.jpg                4617
#
#    _source.price _source.price_range  \
# 0         149.99           100 - 200
# 1         299.99           200 - 500
# 2          74.99            50 - 100
# 3         129.99           100 - 200
# 4         119.99           100 - 200
# 5          99.99            50 - 100
# 6         129.99           100 - 200
# 7         149.99           100 - 200
# 8          89.99            50 - 100
# 9          99.99            50 - 100
#
#                                                          _source.product_name  \
# 0                        Alpine - 12" Dual-Voice-Coil 4-Ohm Subwoofer - Black
# 1                                Alpine - 8" Powered Subwoofer System - Black
# 2             Alpine - Bassline 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 3               JBL - CX Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 4                                      Kenwood - 12" 4-Ohm Subwoofer - Silver
# 5  Kenwood - Performance Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 6                  Kicker - CompR 10" Dual-Voice-Coil 2-Ohm Subwoofer - Black
# 7                  Kicker - CompR 12" Dual-Voice-Coil 2-Ohm Subwoofer - Black
# 8                Kicker - CompS 10" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 9                Kicker - CompS 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
#
#    _source.rating _source.type  \
# 0               3         Subs
# 1               5         Subs
# 2               3         Subs
# 3               6         Subs
# 4               5         Subs
# 5               6         Subs
# 6               6         Subs
# 7               5         Subs
# 8               2         Subs
# 9               3         Subs
#
#                                                                                                                                                                                _source.url  \
# 0                        http://www.bestbuy.com/site/alpine-12-dual-voice-coil-4-ohm-subwoofer-black/4769785.p?id=1218524494220&skuId=4769785&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 1                                http://www.bestbuy.com/site/alpine-8-powered-subwoofer-system-black/9597106.p?id=1219424288868&skuId=9597106&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 2             http://www.bestbuy.com/site/alpine-bassline-12-single-voice-coil-4-ohm-subwoofer-black/8815536.p?id=1218902549936&skuId=8815536&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 3               http://www.bestbuy.com/site/jbl-cx-series-12-single-voice-coil-4-ohm-subwoofer-black/8480035.p?id=1219339620491&skuId=8480035&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 4                                      http://www.bestbuy.com/site/kenwood-12-4-ohm-subwoofer-silver/3581048.p?id=1219599860315&skuId=3581048&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 5  http://www.bestbuy.com/site/kenwood-performance-series-12-single-voice-coil-4-ohm-subwoofer-black/4868454.p?id=1218558349775&skuId=4868454&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 6                  http://www.bestbuy.com/site/kicker-compr-10-dual-voice-coil-2-ohm-subwoofer-black/7705054.p?id=1218858583398&skuId=7705054&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 7                  http://www.bestbuy.com/site/kicker-compr-12-dual-voice-coil-2-ohm-subwoofer-black/7739042.p?id=1218859509037&skuId=7739042&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 8                http://www.bestbuy.com/site/kicker-comps-10-single-voice-coil-4-ohm-subwoofer-black/7738089.p?id=1218859512205&skuId=7738089&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 9                http://www.bestbuy.com/site/kicker-comps-12-single-voice-coil-4-ohm-subwoofer-black/7704107.p?id=1218858583407&skuId=7704107&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
#
#   _type
# 0  _doc
# 1  _doc
# 2  _doc
# 3  _doc
# 4  _doc
# 5  _doc
# 6  _doc
# 7  _doc
# 8  _doc
# 9  _doc

# %% [markdown]
# Better already. But what if I am looking for some subwoofer?

# %%
resp = query_elasticsearch("test_index", query_with_weight('car audio 170 watt'))
display_results(resp)[:6]
# Out:
#        _id      _index     _score _source.brand  \
# 0  4769785  test_index  19.982872        Alpine
# 1  9597106  test_index  19.982872        Alpine
# 2  8815536  test_index  19.982872        Alpine
# 3  8480035  test_index  19.982872           JBL
# 4  3581048  test_index  19.982872       Kenwood
# 5  4868454  test_index  19.982872       Kenwood
#
#                                    _source.categories  \
# 0  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 1  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 2  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 3  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 4  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 5  [Car Electronics & GPS, Car Audio, Car Subwoofers]
#
#                                                                                                                                                                                                                                               _source.description  \
# 0                                                  Listen to music in your vehicle with rich, clear sound with this Alpine SWS-12D4 12" dual-voice-coil 4-ohm subwoofer that features improved thermal capacity and mechanical strength for reliable performance.
# 1     Amplify the bass in your vehicle using this Alpine PWE-S8 subwoofer system that features a compact design you can fit beneath or behind a truck seat, in a sedan trunk or in the hatchback of an SUV. The cast-metal construction ensures long-lasting use.
# 2         Enhance your vehicle's audio system with this Alpine Bassline SWA-12S4 single-voice-coil, 4-ohm subwoofer that handles up to 750W peak power and features a 12" polypropylene/mica woofer cone with a UV-resistant poly foam surround for robust sound.
# 3                       Enjoy powerful low-end sound while you're on the road with this JBL CX Series CX1200 single-voice-coil subwoofer, which features a 12" polypropylene woofer cone for rich, robust audio. The progressive spider delivers optimal control.
# 4  Jam out to your favorite tunes in your vehicle with this 12" Kenwood KFC-W3016PS subwoofer, which features an oversize diaphragm and handles up to 2000W of power (400W RMS) for intense audio. Dual ventilation helps keep the speaker operating efficiently.
# 5                                Experience high-quality sound with this Kenwood Performance Series KFC-W12PS single-voice-coil 4-ohm subwoofer that features a 12" polypropylene cone with a Diamond Array pattern for dynamic sound and enhanced cone strength.
#
#    _source.free_shipping _source.hierarchicalCategories.lvl0  \
# 0                  False               Car Electronics & GPS
# 1                  False               Car Electronics & GPS
# 2                   True               Car Electronics & GPS
# 3                  False               Car Electronics & GPS
# 4                  False               Car Electronics & GPS
# 5                  False               Car Electronics & GPS
#
#   _source.hierarchicalCategories.lvl1  \
# 0   Car Electronics & GPS > Car Audio
# 1   Car Electronics & GPS > Car Audio
# 2   Car Electronics & GPS > Car Audio
# 3   Car Electronics & GPS > Car Audio
# 4   Car Electronics & GPS > Car Audio
# 5   Car Electronics & GPS > Car Audio
#
#                   _source.hierarchicalCategories.lvl2  \
# 0  Car Electronics & GPS > Car Audio > Car Subwoofers
# 1  Car Electronics & GPS > Car Audio > Car Subwoofers
# 2  Car Electronics & GPS > Car Audio > Car Subwoofers
# 3  Car Electronics & GPS > Car Audio > Car Subwoofers
# 4  Car Electronics & GPS > Car Audio > Car Subwoofers
# 5  Car Electronics & GPS > Car Audio > Car Subwoofers
#
#                                          _source.image  _source.popularity  \
# 0  https://cdn-demo.algolia.com/bestbuy/4769785_sb.jpg                9915
# 1  https://cdn-demo.algolia.com/bestbuy/9597106_sb.jpg                9907
# 2  https://cdn-demo.algolia.com/bestbuy/8815536_sb.jpg                9906
# 3  https://cdn-demo.algolia.com/bestbuy/8480035_sb.jpg                4938
# 4  https://cdn-demo.algolia.com/bestbuy/3581048_sb.jpg                4729
# 5  https://cdn-demo.algolia.com/bestbuy/4868454_rb.jpg                4708
#
#    _source.price _source.price_range  \
# 0         149.99           100 - 200
# 1         299.99           200 - 500
# 2          74.99            50 - 100
# 3         129.99           100 - 200
# 4         119.99           100 - 200
# 5          99.99            50 - 100
#
#                                                          _source.product_name  \
# 0                        Alpine - 12" Dual-Voice-Coil 4-Ohm Subwoofer - Black
# 1                                Alpine - 8" Powered Subwoofer System - Black
# 2             Alpine - Bassline 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 3               JBL - CX Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 4                                      Kenwood - 12" 4-Ohm Subwoofer - Silver
# 5  Kenwood - Performance Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
#
#    _source.rating _source.type  \
# 0               3         Subs
# 1               5         Subs
# 2               3         Subs
# 3               6         Subs
# 4               5         Subs
# 5               6         Subs
#
#                                                                                                                                                                                _source.url  \
# 0                        http://www.bestbuy.com/site/alpine-12-dual-voice-coil-4-ohm-subwoofer-black/4769785.p?id=1218524494220&skuId=4769785&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 1                                http://www.bestbuy.com/site/alpine-8-powered-subwoofer-system-black/9597106.p?id=1219424288868&skuId=9597106&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 2             http://www.bestbuy.com/site/alpine-bassline-12-single-voice-coil-4-ohm-subwoofer-black/8815536.p?id=1218902549936&skuId=8815536&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 3               http://www.bestbuy.com/site/jbl-cx-series-12-single-voice-coil-4-ohm-subwoofer-black/8480035.p?id=1219339620491&skuId=8480035&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 4                                      http://www.bestbuy.com/site/kenwood-12-4-ohm-subwoofer-silver/3581048.p?id=1219599860315&skuId=3581048&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 5  http://www.bestbuy.com/site/kenwood-performance-series-12-single-voice-coil-4-ohm-subwoofer-black/4868454.p?id=1218558349775&skuId=4868454&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
#
#   _type
# 0  _doc
# 1  _doc
# 2  _doc
# 3  _doc
# 4  _doc
# 5  _doc

# %% [markdown]
# Unfortunately that query does not work very well :/  Let's see what we can do to fix that

# %% [markdown]
# # 3. Mapping (Schema)

# %%
def create_elasticsearch_mapping(index, mapping):
    # ignore 400 cause by IndexAlreadyExistsException when creating an index
    return es_client.indices.create(index=index, body=mapping, ignore=400)

def delete_elasticsearch_mapping(index):
    return es_client.indices.delete(index=index, ignore=[400, 404])

# %% [markdown]
# Each field has a data type which can be:
#
# * a simple type like text, keyword, date, long, double, boolean or ip.
# * a type which supports the hierarchical nature of JSON such as object or nested.
# * a specialised type like geo_point, geo_shape, or completion.

# %%
es_mapping = {
    "mappings": {
        "properties": {
            "product_name":           { "type": "text" },  
            "description":            { "type": "text" },
            "categories":             { "type": "text" },
            "hierarchicalCategories": {
                "type": "nested",
                "include_in_parent": "true",
                "properties": {
                    "lvl0": {"type": "text"},
                    "lvl1": {"type": "text"},
                    "lvl2": {"type": "text"},
                    "lvl3": {"type": "text"},
                    "lvl4": {"type": "text"}
                }
            },
            "type":                   { "type": "text" },
            "brand":                  { "type": "text" },
            "url":                    { "type": "text", "index" : False },
            "image":                  { "type": "text", "index" : False },
            "popularity":             { "type": "double" },
            "price":                  { "type": "text" },
            "price_range":            { "type": "keyword" },
            "rating":                 { "type": "short" },
            "free_shipping":          { "type": "boolean" }
    }
  }
}

delete_elasticsearch_mapping('test-w-mapping')
create_elasticsearch_mapping("test-w-mapping", es_mapping)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'test-w-mapping'}

# %%
load_data(es_client, 'test-w-mapping', df)
# Out:
# (10000, [])

# %%
resp = query_elasticsearch("test-w-mapping", query_with_weight("car audio 170 watt"))
display_results(resp)[:10]
# Out:
#        _id          _index     _score _source.brand  \
# 0  4769785  test-w-mapping  19.982872        Alpine
# 1  9597106  test-w-mapping  19.982872        Alpine
# 2  8815536  test-w-mapping  19.982872        Alpine
# 3  8480035  test-w-mapping  19.982872           JBL
# 4  3581048  test-w-mapping  19.982872       Kenwood
# 5  4868454  test-w-mapping  19.982872       Kenwood
# 6  7705054  test-w-mapping  19.982872        Kicker
# 7  7739042  test-w-mapping  19.982872        Kicker
# 8  7738089  test-w-mapping  19.982872        Kicker
# 9  7704107  test-w-mapping  19.982872        Kicker
#
#                                    _source.categories  \
# 0  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 1  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 2  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 3  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 4  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 5  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 6  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 7  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 8  [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 9  [Car Electronics & GPS, Car Audio, Car Subwoofers]
#
#                                                                                                                                                                                                                                               _source.description  \
# 0                                                  Listen to music in your vehicle with rich, clear sound with this Alpine SWS-12D4 12" dual-voice-coil 4-ohm subwoofer that features improved thermal capacity and mechanical strength for reliable performance.
# 1     Amplify the bass in your vehicle using this Alpine PWE-S8 subwoofer system that features a compact design you can fit beneath or behind a truck seat, in a sedan trunk or in the hatchback of an SUV. The cast-metal construction ensures long-lasting use.
# 2         Enhance your vehicle's audio system with this Alpine Bassline SWA-12S4 single-voice-coil, 4-ohm subwoofer that handles up to 750W peak power and features a 12" polypropylene/mica woofer cone with a UV-resistant poly foam surround for robust sound.
# 3                       Enjoy powerful low-end sound while you're on the road with this JBL CX Series CX1200 single-voice-coil subwoofer, which features a 12" polypropylene woofer cone for rich, robust audio. The progressive spider delivers optimal control.
# 4  Jam out to your favorite tunes in your vehicle with this 12" Kenwood KFC-W3016PS subwoofer, which features an oversize diaphragm and handles up to 2000W of power (400W RMS) for intense audio. Dual ventilation helps keep the speaker operating efficiently.
# 5                                Experience high-quality sound with this Kenwood Performance Series KFC-W12PS single-voice-coil 4-ohm subwoofer that features a 12" polypropylene cone with a Diamond Array pattern for dynamic sound and enhanced cone strength.
# 6        Enhance your vehicle's audio system with this Kicker CompR 40CWR102 dual-voice-coil 2-ohm subwoofer that features a 10" injection-molded polypropylene cone for rich, deep sound. Quad Venting slots help ensure cool operation for optimal performance.
# 7         This Kicker CompR 40CWR122 subwoofer features a 12" injection-molded polypropylene woofer cone and a large-diameter, progressive-roll spider with Spiralead tinsel leads to enhance your vehicle's music, so you can enjoy rich, crisp audio on the go.
# 8                                         Enhance your vehicle's audio system with this Kicker CompS 40CWS104 single-voice-coil subwoofer that features a 10" polypropylene woofer cone and handles up to 600W peak power to deliver an intense audio experience.
# 9    Enjoy your music with this Kicker CompS 40CWS124 single-voice-coil 4-ohm subwoofer, which features a 12" polypropylene cone with a foam surround for rich sound. The rip-resistant, large-diameter spider with Spiralead technology helps ensure durability.
#
#    _source.free_shipping _source.hierarchicalCategories.lvl0  \
# 0                  False               Car Electronics & GPS
# 1                  False               Car Electronics & GPS
# 2                   True               Car Electronics & GPS
# 3                  False               Car Electronics & GPS
# 4                  False               Car Electronics & GPS
# 5                  False               Car Electronics & GPS
# 6                  False               Car Electronics & GPS
# 7                  False               Car Electronics & GPS
# 8                  False               Car Electronics & GPS
# 9                  False               Car Electronics & GPS
#
#   _source.hierarchicalCategories.lvl1  \
# 0   Car Electronics & GPS > Car Audio
# 1   Car Electronics & GPS > Car Audio
# 2   Car Electronics & GPS > Car Audio
# 3   Car Electronics & GPS > Car Audio
# 4   Car Electronics & GPS > Car Audio
# 5   Car Electronics & GPS > Car Audio
# 6   Car Electronics & GPS > Car Audio
# 7   Car Electronics & GPS > Car Audio
# 8   Car Electronics & GPS > Car Audio
# 9   Car Electronics & GPS > Car Audio
#
#                   _source.hierarchicalCategories.lvl2  \
# 0  Car Electronics & GPS > Car Audio > Car Subwoofers
# 1  Car Electronics & GPS > Car Audio > Car Subwoofers
# 2  Car Electronics & GPS > Car Audio > Car Subwoofers
# 3  Car Electronics & GPS > Car Audio > Car Subwoofers
# 4  Car Electronics & GPS > Car Audio > Car Subwoofers
# 5  Car Electronics & GPS > Car Audio > Car Subwoofers
# 6  Car Electronics & GPS > Car Audio > Car Subwoofers
# 7  Car Electronics & GPS > Car Audio > Car Subwoofers
# 8  Car Electronics & GPS > Car Audio > Car Subwoofers
# 9  Car Electronics & GPS > Car Audio > Car Subwoofers
#
#                                          _source.image  _source.popularity  \
# 0  https://cdn-demo.algolia.com/bestbuy/4769785_sb.jpg                9915
# 1  https://cdn-demo.algolia.com/bestbuy/9597106_sb.jpg                9907
# 2  https://cdn-demo.algolia.com/bestbuy/8815536_sb.jpg                9906
# 3  https://cdn-demo.algolia.com/bestbuy/8480035_sb.jpg                4938
# 4  https://cdn-demo.algolia.com/bestbuy/3581048_sb.jpg                4729
# 5  https://cdn-demo.algolia.com/bestbuy/4868454_rb.jpg                4708
# 6  https://cdn-demo.algolia.com/bestbuy/7705054_sb.jpg                4622
# 7  https://cdn-demo.algolia.com/bestbuy/7739042_sb.jpg                4620
# 8  https://cdn-demo.algolia.com/bestbuy/7738089_sb.jpg                4618
# 9  https://cdn-demo.algolia.com/bestbuy/7704107_sb.jpg                4617
#
#    _source.price _source.price_range  \
# 0         149.99           100 - 200
# 1         299.99           200 - 500
# 2          74.99            50 - 100
# 3         129.99           100 - 200
# 4         119.99           100 - 200
# 5          99.99            50 - 100
# 6         129.99           100 - 200
# 7         149.99           100 - 200
# 8          89.99            50 - 100
# 9          99.99            50 - 100
#
#                                                          _source.product_name  \
# 0                        Alpine - 12" Dual-Voice-Coil 4-Ohm Subwoofer - Black
# 1                                Alpine - 8" Powered Subwoofer System - Black
# 2             Alpine - Bassline 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 3               JBL - CX Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 4                                      Kenwood - 12" 4-Ohm Subwoofer - Silver
# 5  Kenwood - Performance Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 6                  Kicker - CompR 10" Dual-Voice-Coil 2-Ohm Subwoofer - Black
# 7                  Kicker - CompR 12" Dual-Voice-Coil 2-Ohm Subwoofer - Black
# 8                Kicker - CompS 10" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 9                Kicker - CompS 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
#
#    _source.rating _source.type  \
# 0               3         Subs
# 1               5         Subs
# 2               3         Subs
# 3               6         Subs
# 4               5         Subs
# 5               6         Subs
# 6               6         Subs
# 7               5         Subs
# 8               2         Subs
# 9               3         Subs
#
#                                                                                                                                                                                _source.url  \
# 0                        http://www.bestbuy.com/site/alpine-12-dual-voice-coil-4-ohm-subwoofer-black/4769785.p?id=1218524494220&skuId=4769785&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 1                                http://www.bestbuy.com/site/alpine-8-powered-subwoofer-system-black/9597106.p?id=1219424288868&skuId=9597106&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 2             http://www.bestbuy.com/site/alpine-bassline-12-single-voice-coil-4-ohm-subwoofer-black/8815536.p?id=1218902549936&skuId=8815536&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 3               http://www.bestbuy.com/site/jbl-cx-series-12-single-voice-coil-4-ohm-subwoofer-black/8480035.p?id=1219339620491&skuId=8480035&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 4                                      http://www.bestbuy.com/site/kenwood-12-4-ohm-subwoofer-silver/3581048.p?id=1219599860315&skuId=3581048&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 5  http://www.bestbuy.com/site/kenwood-performance-series-12-single-voice-coil-4-ohm-subwoofer-black/4868454.p?id=1218558349775&skuId=4868454&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 6                  http://www.bestbuy.com/site/kicker-compr-10-dual-voice-coil-2-ohm-subwoofer-black/7705054.p?id=1218858583398&skuId=7705054&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 7                  http://www.bestbuy.com/site/kicker-compr-12-dual-voice-coil-2-ohm-subwoofer-black/7739042.p?id=1218859509037&skuId=7739042&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 8                http://www.bestbuy.com/site/kicker-comps-10-single-voice-coil-4-ohm-subwoofer-black/7738089.p?id=1218859512205&skuId=7738089&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 9                http://www.bestbuy.com/site/kicker-comps-12-single-voice-coil-4-ohm-subwoofer-black/7704107.p?id=1218858583407&skuId=7704107&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
#
#   _type
# 0  _doc
# 1  _doc
# 2  _doc
# 3  _doc
# 4  _doc
# 5  _doc
# 6  _doc
# 7  _doc
# 8  _doc
# 9  _doc

# %% [markdown]
# Still not working ...

# %% [markdown]
# # 4. Analyzers

# %% [markdown]
# <img src="https://www.elastic.co/guide/en/elasticsearch/client/net-api/current/analysis-chain.png" alt="analyzers in elasticsearch" width="600"/>

# %% [markdown]
# One possible solution is to convert the char during analysis. Let's add the `char_filter` to the default `standard` analyzer (https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-standard-analyzer.html)

# %%
es_mapping_v2 = {
    "settings" : {
        "analysis": {
            "analyzer": {
                "my_analyzer": {
                    "char_filter": ["my_char_filter"],
                    "tokenizer": "standard",
                    "filter": [
                        "my_synonyms"
                    ]
                }
            },
            "char_filter": {
                "my_char_filter": {
                    "type": "pattern_replace",
                    "pattern": "([0-9]+)W",
                    "replacement": "$1 watt"
                }
            },
            "filter": {
                "my_synonyms": {
                  "type": "synonym",
                  "synonyms": [
                    "sub, subwoofer"
                  ]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "product_name":           { "type": "text" },  
            "description":            { "type": "text" , "analyzer": "my_analyzer" },
            "categories":             { "type": "text" },
            "hierarchicalCategories": {
                "type": "nested",
                "include_in_parent": "true",
                "properties": {
                    "lvl0": {"type": "text"},
                    "lvl1": {"type": "text"},
                    "lvl2": {"type": "text"},
                    "lvl3": {"type": "text"},
                    "lvl4": {"type": "text"}
                }
            },
            "type":                   { "type": "text" },
            "brand":                  { "type": "text" },
            "url":                    { "type": "text", "index" : False },
            "image":                  { "type": "text", "index" : False },
            "popularity":             { "type": "double" },
            "price":                  { "type": "text" },
            "price_range":            { "type": "keyword" },
            "rating":                 { "type": "short" },
            "free_shipping":          { "type": "boolean" }
    }
  }
}

delete_elasticsearch_mapping("test-w-mapping-v2")
create_elasticsearch_mapping("test-w-mapping-v2", es_mapping_v2)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'test-w-mapping-v2'}

# %% [markdown]
# Let's load some data in our new index

# %%
load_data(es_client, 'test-w-mapping-v2', df)
# Out:
# (10000, [])

# %% [markdown]
# Let's see if that works!

# %%
resp = query_elasticsearch('test-w-mapping-v2', query_with_weight("car audio 170 watt"))
display_results(resp)[:10]
# Out:
#        _id             _index     _score _source.brand  \
# 0  7551355  test-w-mapping-v2  37.615290        Alpine
# 1  8063027  test-w-mapping-v2  25.947002       Pioneer
# 2  7752088  test-w-mapping-v2  23.700737        Kicker
# 3  7709236  test-w-mapping-v2  21.380913        Kicker
# 4  5273007  test-w-mapping-v2  21.233932          Sony
# 5  4330830  test-w-mapping-v2  20.194906       Pioneer
# 6  4769785  test-w-mapping-v2  19.982872        Alpine
# 7  9597106  test-w-mapping-v2  19.982872        Alpine
# 8  8815536  test-w-mapping-v2  19.982872        Alpine
# 9  8480035  test-w-mapping-v2  19.982872           JBL
#
#                                                      _source.categories  \
# 0  [Car Electronics & GPS, Car Audio, Car Speakers, 5.25" Car Speakers]
# 1  [Car Electronics & GPS, Car Audio, Car Speakers, 5.25" Car Speakers]
# 2                 [Car Electronics & GPS, Car Audio, Loaded Enclosures]
# 3   [Car Electronics & GPS, Car Audio, Car Speakers, 6.5" Car Speakers]
# 4                 [Audio, Home Audio, Home Theater Systems, Sound Bars]
# 5   [Car Electronics & GPS, Car Audio, Car Speakers, 6.5" Car Speakers]
# 6                    [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 7                    [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 8                    [Car Electronics & GPS, Car Audio, Car Subwoofers]
# 9                    [Car Electronics & GPS, Car Audio, Car Subwoofers]
#
#                                                                                                                                                                                                                                                                                                    _source.description  \
# 0                                                                                 Upgrade your car audio system with these Alpine Type-S SPS-510 2-way coaxial car speakers, which handle up to 170W peak power and feature 5-1/4" poly-mica woofer cones and 3/4" silk-dome tweeters for a wide range of frequencies.
# 1                                                                              Enjoy your favorite music in your car with these Pioneer TS-G1345R 2-way car speakers, which feature 250W maximum power handling to deliver sounds in robust detail. The rubber-coated cloth surrounds help ensure high-fidelity audio.
# 2                                                                                                        Upgrade your car audio system with this Kicker TCompS10 40TCWS104 single-voice-coil subwoofer, which handles up to 600W peak power for deep bass sound and includes a ported box for simplified installation.
# 3                                                                              With 6-3/4" polypropylene woofer cones and 1/2" PEI balanced-dome tweeters, these Kicker 40CS674 coaxial car speakers deliver a wide range of sound and handle up to 300W peak power, so you can enjoy vibrant, robust audio on the go.
# 4                                                                      Designed for use with most 32" to 55" TVs, this Sony HTXT1 sound system's integrated full-range speakers and dual built-in subwoofers enrich your favorite TV shows, movies and games. The 170W S-Master amplifier effectively powers the unit.
# 5  Pioneer Car Speakers: Enjoy enhanced bass response in your vehicle with these car speakers, which feature a 3-way design with a multilayer mica matrix cone and up to 320W max power for robust audio performance.  Geek Squad&#174; Installation Recommended Visit your local Best Buy store for more information.
# 6                                                                                                       Listen to music in your vehicle with rich, clear sound with this Alpine SWS-12D4 12" dual-voice-coil 4-ohm subwoofer that features improved thermal capacity and mechanical strength for reliable performance.
# 7                                                          Amplify the bass in your vehicle using this Alpine PWE-S8 subwoofer system that features a compact design you can fit beneath or behind a truck seat, in a sedan trunk or in the hatchback of an SUV. The cast-metal construction ensures long-lasting use.
# 8                                                              Enhance your vehicle's audio system with this Alpine Bassline SWA-12S4 single-voice-coil, 4-ohm subwoofer that handles up to 750W peak power and features a 12" polypropylene/mica woofer cone with a UV-resistant poly foam surround for robust sound.
# 9                                                                            Enjoy powerful low-end sound while you're on the road with this JBL CX Series CX1200 single-voice-coil subwoofer, which features a 12" polypropylene woofer cone for rich, robust audio. The progressive spider delivers optimal control.
#
#    _source.free_shipping _source.hierarchicalCategories.lvl0  \
# 0                  False               Car Electronics & GPS
# 1                  False               Car Electronics & GPS
# 2                  False               Car Electronics & GPS
# 3                  False               Car Electronics & GPS
# 4                  False                               Audio
# 5                  False               Car Electronics & GPS
# 6                  False               Car Electronics & GPS
# 7                  False               Car Electronics & GPS
# 8                   True               Car Electronics & GPS
# 9                  False               Car Electronics & GPS
#
#   _source.hierarchicalCategories.lvl1  \
# 0   Car Electronics & GPS > Car Audio
# 1   Car Electronics & GPS > Car Audio
# 2   Car Electronics & GPS > Car Audio
# 3   Car Electronics & GPS > Car Audio
# 4                  Audio > Home Audio
# 5   Car Electronics & GPS > Car Audio
# 6   Car Electronics & GPS > Car Audio
# 7   Car Electronics & GPS > Car Audio
# 8   Car Electronics & GPS > Car Audio
# 9   Car Electronics & GPS > Car Audio
#
#                      _source.hierarchicalCategories.lvl2  \
# 0       Car Electronics & GPS > Car Audio > Car Speakers
# 1       Car Electronics & GPS > Car Audio > Car Speakers
# 2  Car Electronics & GPS > Car Audio > Loaded Enclosures
# 3       Car Electronics & GPS > Car Audio > Car Speakers
# 4              Audio > Home Audio > Home Theater Systems
# 5       Car Electronics & GPS > Car Audio > Car Speakers
# 6     Car Electronics & GPS > Car Audio > Car Subwoofers
# 7     Car Electronics & GPS > Car Audio > Car Subwoofers
# 8     Car Electronics & GPS > Car Audio > Car Subwoofers
# 9     Car Electronics & GPS > Car Audio > Car Subwoofers
#
#                                      _source.hierarchicalCategories.lvl3  \
# 0  Car Electronics & GPS > Car Audio > Car Speakers > 5.25" Car Speakers
# 1  Car Electronics & GPS > Car Audio > Car Speakers > 5.25" Car Speakers
# 2                                                                    NaN
# 3   Car Electronics & GPS > Car Audio > Car Speakers > 6.5" Car Speakers
# 4                 Audio > Home Audio > Home Theater Systems > Sound Bars
# 5   Car Electronics & GPS > Car Audio > Car Speakers > 6.5" Car Speakers
# 6                                                                    NaN
# 7                                                                    NaN
# 8                                                                    NaN
# 9                                                                    NaN
#
#                                          _source.image  _source.popularity  \
# 0  https://cdn-demo.algolia.com/bestbuy/7551355_sb.jpg                9899
# 1  https://cdn-demo.algolia.com/bestbuy/8063027_sb.jpg                2101
# 2  https://cdn-demo.algolia.com/bestbuy/7752088_sb.jpg                4599
# 3  https://cdn-demo.algolia.com/bestbuy/7709236_sb.jpg                4627
# 4  https://cdn-demo.algolia.com/bestbuy/5273007_sb.jpg                 433
# 5  https://cdn-demo.algolia.com/bestbuy/4330830_sb.jpg                2090
# 6  https://cdn-demo.algolia.com/bestbuy/4769785_sb.jpg                9915
# 7  https://cdn-demo.algolia.com/bestbuy/9597106_sb.jpg                9907
# 8  https://cdn-demo.algolia.com/bestbuy/8815536_sb.jpg                9906
# 9  https://cdn-demo.algolia.com/bestbuy/8480035_sb.jpg                4938
#
#    _source.price _source.price_range  \
# 0          89.99            50 - 100
# 1          49.99              1 - 50
# 2         149.99           100 - 200
# 3          79.99            50 - 100
# 4         299.99           200 - 500
# 5          79.99            50 - 100
# 6         149.99           100 - 200
# 7         299.99           200 - 500
# 8          74.99            50 - 100
# 9         129.99           100 - 200
#
#                                                                     _source.product_name  \
# 0  Alpine - Type-S 5-1/4" 2-Way Coaxial Car Speakers with Poly-Mica Cones (Pair) - Black
# 1           Pioneer - 5-1/4" 2-Way Car Speakers with IMPP Composite Cones (Pair) - Black
# 2         Kicker - TCompS10 10" Single-Voice-Coil 4-Ohm Subwoofer with Enclosure - Black
# 3           Kicker - 6-3/4" Coaxial Car Speakers with Polypropylene Cones (Pair) - Black
# 4               Sony - 2.1-Channel TV Sound System with Dual Built-In Subwoofers - Black
# 5                Pioneer - 6.5" 3-Way Car Speakers with Mica Matrix Cones (Pair) - Black
# 6                                   Alpine - 12" Dual-Voice-Coil 4-Ohm Subwoofer - Black
# 7                                           Alpine - 8" Powered Subwoofer System - Black
# 8                        Alpine - Bassline 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
# 9                          JBL - CX Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black
#
#    _source.rating _source.type  \
# 0               5     Speakers
# 1               2     Speakers
# 2               3         Subs
# 3               2     Speakers
# 4               6    Soundbars
# 5               5     Speakers
# 6               3         Subs
# 7               5         Subs
# 8               3         Subs
# 9               6         Subs
#
#                                                                                                                                                                                         _source.url  \
# 0  http://www.bestbuy.com/site/alpine-type-s-5-1-4-2-way-coaxial-car-speakers-with-poly-mica-cones-pair-black/7551355.p?id=1218853533848&skuId=7551355&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 1           http://www.bestbuy.com/site/pioneer-5-1-4-2-way-car-speakers-with-impp-composite-cones-pair-black/8063027.p?id=1219309055448&skuId=8063027&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 2       http://www.bestbuy.com/site/kicker-tcomps10-10-single-voice-coil-4-ohm-subwoofer-with-enclosure-black/7752088.p?id=1218859509039&skuId=7752088&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 3           http://www.bestbuy.com/site/kicker-6-3-4-coaxial-car-speakers-with-polypropylene-cones-pair-black/7709236.p?id=1218858759391&skuId=7709236&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 4            http://www.bestbuy.com/site/sony-2-1-channel-tv-sound-system-with-dual-built-in-subwoofers-black/5273007.p?id=1219117626218&skuId=5273007&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 5                http://www.bestbuy.com/site/pioneer-6-5-3-way-car-speakers-with-mica-matrix-cones-pair-black/4330830.p?id=1219731657786&skuId=4330830&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 6                                 http://www.bestbuy.com/site/alpine-12-dual-voice-coil-4-ohm-subwoofer-black/4769785.p?id=1218524494220&skuId=4769785&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 7                                         http://www.bestbuy.com/site/alpine-8-powered-subwoofer-system-black/9597106.p?id=1219424288868&skuId=9597106&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 8                      http://www.bestbuy.com/site/alpine-bassline-12-single-voice-coil-4-ohm-subwoofer-black/8815536.p?id=1218902549936&skuId=8815536&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
# 9                        http://www.bestbuy.com/site/jbl-cx-series-12-single-voice-coil-4-ohm-subwoofer-black/8480035.p?id=1219339620491&skuId=8480035&cmp=RMX&ky=1uWSHMdQqBeVJB9cXgEke60s5EjfS6M1W
#
#   _type
# 0  _doc
# 1  _doc
# 2  _doc
# 3  _doc
# 4  _doc
# 5  _doc
# 6  _doc
# 7  _doc
# 8  _doc
# 9  _doc

# %% [markdown]
# Finally it works!

# %% [markdown]
# # Let's build a search engine!

# %%
def search_engine(phrase):
    resp = query_elasticsearch('test-w-mapping-v2', query_with_weight(phrase))
    
    # Get item from response
    items = [res['_source'] for res in resp['hits']['hits']]
    
    item_template = """
      <tr>
        <th style="width: 100px"><img src="{image}"></th>
        <th>{name}</th>
        <th>{brand}</th>
        <th>{description}</th>
      </tr>
    """

    page = ""
    page += """<table style="width: 70%">"""
    for row in items:
        page += item_template.format(image=row['image'], name=row['product_name'], brand=row['brand'], description=row['description'])
    page += "</table>"

    return page

# %%
HTML(search_engine("car audio 170 watt"))
# Out:
# <table style="width: 70%">
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/7551355_sb.jpg"></th>
#         <th>Alpine - Type-S 5-1/4" 2-Way Coaxial Car Speakers with Poly-Mica Cones (Pair) - Black</th>
#         <th>Alpine</th>
#         <th>Upgrade your car audio system with these Alpine Type-S SPS-510 2-way coaxial car speakers, which handle up to 170W peak power and feature 5-1/4" poly-mica woofer cones and 3/4" silk-dome tweeters for a wide range of frequencies.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/8063027_sb.jpg"></th>
#         <th>Pioneer - 5-1/4" 2-Way Car Speakers with IMPP Composite Cones (Pair) - Black</th>
#         <th>Pioneer</th>
#         <th>Enjoy your favorite music in your car with these Pioneer TS-G1345R 2-way car speakers, which feature 250W maximum power handling to deliver sounds in robust detail. The rubber-coated cloth surrounds help ensure high-fidelity audio.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/7752088_sb.jpg"></th>
#         <th>Kicker - TCompS10 10" Single-Voice-Coil 4-Ohm Subwoofer with Enclosure - Black</th>
#         <th>Kicker</th>
#         <th>Upgrade your car audio system with this Kicker TCompS10 40TCWS104 single-voice-coil subwoofer, which handles up to 600W peak power for deep bass sound and includes a ported box for simplified installation.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/7709236_sb.jpg"></th>
#         <th>Kicker - 6-3/4" Coaxial Car Speakers with Polypropylene Cones (Pair) - Black</th>
#         <th>Kicker</th>
#         <th>With 6-3/4" polypropylene woofer cones and 1/2" PEI balanced-dome tweeters, these Kicker 40CS674 coaxial car speakers deliver a wide range of sound and handle up to 300W peak power, so you can enjoy vibrant, robust audio on the go.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/5273007_sb.jpg"></th>
#         <th>Sony - 2.1-Channel TV Sound System with Dual Built-In Subwoofers - Black</th>
#         <th>Sony</th>
#         <th>Designed for use with most 32" to 55" TVs, this Sony HTXT1 sound system's integrated full-range speakers and dual built-in subwoofers enrich your favorite TV shows, movies and games. The 170W S-Master amplifier effectively powers the unit.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/4330830_sb.jpg"></th>
#         <th>Pioneer - 6.5" 3-Way Car Speakers with Mica Matrix Cones (Pair) - Black</th>
#         <th>Pioneer</th>
#         <th>Pioneer Car Speakers: Enjoy enhanced bass response in your vehicle with these car speakers, which feature a 3-way design with a multilayer mica matrix cone and up to 320W max power for robust audio performance.  Geek Squad&#174; Installation Recommended Visit your local Best Buy store for more information.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/4769785_sb.jpg"></th>
#         <th>Alpine - 12" Dual-Voice-Coil 4-Ohm Subwoofer - Black</th>
#         <th>Alpine</th>
#         <th>Listen to music in your vehicle with rich, clear sound with this Alpine SWS-12D4 12" dual-voice-coil 4-ohm subwoofer that features improved thermal capacity and mechanical strength for reliable performance.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/9597106_sb.jpg"></th>
#         <th>Alpine - 8" Powered Subwoofer System - Black</th>
#         <th>Alpine</th>
#         <th>Amplify the bass in your vehicle using this Alpine PWE-S8 subwoofer system that features a compact design you can fit beneath or behind a truck seat, in a sedan trunk or in the hatchback of an SUV. The cast-metal construction ensures long-lasting use.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/8815536_sb.jpg"></th>
#         <th>Alpine - Bassline 12" Single-Voice-Coil 4-Ohm Subwoofer - Black</th>
#         <th>Alpine</th>
#         <th>Enhance your vehicle's audio system with this Alpine Bassline SWA-12S4 single-voice-coil, 4-ohm subwoofer that handles up to 750W peak power and features a 12" polypropylene/mica woofer cone with a UV-resistant poly foam surround for robust sound.</th>
#       </tr>
#
#       <tr>
#         <th style="width: 100px"><img src="https://cdn-demo.algolia.com/bestbuy/8480035_sb.jpg"></th>
#         <th>JBL - CX Series 12" Single-Voice-Coil 4-Ohm Subwoofer - Black</th>
#         <th>JBL</th>
#         <th>Enjoy powerful low-end sound while you're on the road with this JBL CX Series CX1200 single-voice-coil subwoofer, which features a 12" polypropylene woofer cone for rich, robust audio. The progressive spider delivers optimal control.</th>
#       </tr>
#     </table>
